# %% [markdown]
# Imports and loadins from CSV:

# %%
from bookstats.config import RAW_DATA, CLEAN_DATA
import pandas as pd
import matplotlib.pyplot as plt

raw_data = pd.read_csv(RAW_DATA)
clean_data = pd.read_csv(CLEAN_DATA)

# %% [markdown]
# Checking filtering out non-English books:
