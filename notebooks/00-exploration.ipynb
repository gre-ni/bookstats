# %% [markdown]
# Questions:
#
# Technical:
# - How do I clean authors names? There seems to be a mix between authors, translators and even illustrators in the same column string
#     - How can I verify something based on a name? Either translator/author or gender, country of origin etc.
#     - How can I figure out the split if someone uses spaces?
# - First work with only what's in English
# - Eventually, how do I split csv into multiple tables, while preserving relationships?
#
#
# To explore: ratings:
# - does number of pages influence rating?
# - which publisher has on average highest rating?
# - highest rated books, top 100 for example -> how many of those are further in a series, can I verify that somehow? how can I explore this relationship?
# - does number of ratings influence the outcome? i.e more widely popular book tends to attract people outside of that niche, therefore has harsher critics?
# - same book in multiple languages, does it have different ratings?
#
# - authors who write in english but are from different countries
#
#
# To visualise:
# - publishers pie chart kind of thing
# - spread of from which years the books are

# %%
import sys
from bookstats.config import DB_PATH, RAW_DATA
