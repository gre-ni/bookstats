# %% [markdown]
# Notes to remember:
#
# - cast page count float into int, preserving NULL values
# - series part number is text in df, due to regex parse from string title -> convert at seeding

# %% [markdown]
# Strategy:
#
# - some cleaning happened prior, but modelling happens after loading, making use of SQLite assigning keys natively (ELT)
